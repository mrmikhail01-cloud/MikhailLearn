# %% [markdown]
# # "Задание 1"

# %%
value = (7 * 5) / 8
value = value + 5
value = value / (3 ** 5)
print(value)
# Out:
# 0.038580246913580245

# %% [markdown]
# # "Задание 2"

# %%
v = int(input())
t = int(input())
print(v * t %109)
# Out:
#  40
#  2
# 80

# %% [markdown]
# # "Задание 3"

# %%
a = float(input())
b = float(input())

result = a * (a > b) + b * (b > a)
print(result)
# Out:
#  1000
#  400
# 1000.0
